# %% [markdown]
# **Stock Price Analysis of 3 renowned financial institutions during COVID19**
#
# **Prepared by Mirza Razin Alam 101329992**

# %%
# !pip install pandas_datareader

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
# %matplotlib inline

# %%
# Create start and end variables
start = datetime.datetime(2019,1,1)
end = datetime.datetime(2020,12,31)

# %%
# JP Morgan
JPM = data.DataReader('JPM','yahoo',start,end)
# Bank of America
BAC = data.DataReader('BAC','yahoo',start,end)
# Wells Fargo Bank
WFC = data.DataReader('WFC','yahoo', start,end)

# %%
tickers = ['JPM','BAC','WFC']

# %%
fin_stocks = pd.concat([JPM,BAC,WFC], axis = 1, keys = tickers)

# %%
fin_stocks.columns.names = ['Consumer Ticker','Stock Info']

# %%
fin_stocks.head()
# Out:
# Consumer Ticker         JPM                                                 \
# Stock Info             High        Low        Open       Close      Volume
# Date
# 2019-01-02        99.779999  95.940002   95.949997   99.309998  15670900.0
# 2019-01-03        98.889999  96.690002   98.639999   97.110001  16286400.0
# 2019-01-04       100.930000  98.279999   99.110001  100.690002  16935200.0
# 2019-01-07       101.470001  99.709999  100.430000  100.760002  15430700.0
# 2019-01-08       101.820000  99.550003  101.629997  100.570000  13578800.0
#
# Consumer Ticker                   BAC                                   \
# Stock Info       Adj Close       High        Low       Open      Close
# Date
# 2019-01-02       91.723846  25.139999  24.010000  24.080000  24.959999
# 2019-01-03       90.420296  25.040001  24.450001  24.940001  24.559999
# 2019-01-04       93.753693  25.650000  25.030001  25.100000  25.580000
# 2019-01-07       93.818863  25.780001  25.290001  25.559999  25.559999
# ...

# %%
fin_stocks
# Out:
# Consumer Ticker         JPM                                                  \
# Stock Info             High         Low        Open       Close      Volume
# Date
# 2019-01-02        99.779999   95.940002   95.949997   99.309998  15670900.0
# 2019-01-03        98.889999   96.690002   98.639999   97.110001  16286400.0
# 2019-01-04       100.930000   98.279999   99.110001  100.690002  16935200.0
# 2019-01-07       101.470001   99.709999  100.430000  100.760002  15430700.0
# 2019-01-08       101.820000   99.550003  101.629997  100.570000  13578800.0
# ...                     ...         ...         ...         ...         ...
# 2020-12-24       125.550003  123.570000  125.089996  124.519997   4164900.0
# 2020-12-28       126.650002  124.790001  125.820000  125.339996   8072600.0
# 2020-12-29       126.279999  124.889999  126.199997  125.010002   8389200.0
# 2020-12-30       125.849998  124.900002  125.489998  125.360001   7398000.0
# ...

# %%
#Saving as csv file for data cleaning
fin_stocks.to_csv('Fin_Stock.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Loading cleaned dataset
clean_finstock= pd.read_csv('Fin_Stock1.csv')
clean_finstock
# Out:
#            Date  JPM_Price  BAC_Price  WFC_Price
# 0      1/2/2019      91.72      23.65      43.15
# 1      1/3/2019      90.42      23.27      42.81
# 2      1/4/2019      93.75      24.24      44.08
# 3      1/7/2019      93.82      24.22      43.80
# 4      1/8/2019      93.64      24.17      43.70
# ..          ...        ...        ...        ...
# 500  12/24/2020     122.91      29.81      29.68
# 501  12/28/2020     123.72      29.98      29.77
# 502  12/29/2020     123.39      29.86      29.62
# 503  12/30/2020     123.73      29.83      29.59
# 504  12/31/2020     125.42      30.16      30.02
#
# [505 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for tick in tickers:
    consumer_stocks[tick]['Adj Close'].plot(label = tick, figsize = (12,5))
plt.legend()

# %%
#Checking for NULL values
clean_finstock.isnull().sum()
# Out:
# Date         0
# JPM_Price    0
# BAC_Price    0
# WFC_Price    0
# dtype: int64

# %%
#Running descriptive statistics on the data set
clean_finstock.describe()
# Out:
#         JPM_Price   BAC_Price   WFC_Price
# count  505.000000  505.000000  505.000000
# mean   105.409485   27.045822   37.591030
# std     13.203423    3.406228   10.235374
# min     75.760000   17.630000   20.930000
# 25%     96.000000   24.550000   25.980000
# 50%    102.070000   27.090000   43.070000
# 75%    113.990000   28.690000   45.910000
# max    134.380000   34.540000   52.080000

# %%
#Checking for outliers in JPM stock price
plt.boxplot(clean_finstock.JPM_Price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x199de9b66d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x199de9b6d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x199de9b6370>],
#  'medians': [<matplotlib.lines.Line2D at 0x199de846490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x199de8467f0>],
#  'means': []}

# %%
#Checking for outliers in BAC stock price
plt.boxplot(clean_finstock.BAC_Price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x199de892b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x199de89f220>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x199de892790>],
#  'medians': [<matplotlib.lines.Line2D at 0x199de89f8e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x199de89fc40>],
#  'means': []}

# %%
#Checking for outliers in WFC stock price
plt.boxplot(clean_finstock.WFC_Price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x199de8f49d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x199de901040>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x199de8f4730>],
#  'medians': [<matplotlib.lines.Line2D at 0x199de901700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x199de901a60>],
#  'means': []}

# %%
#Checking for Skewness
from scipy.stats import skew

print(skew(clean_finstock['JPM_Price']))
print(skew(clean_finstock['BAC_Price']))
print(skew(clean_finstock['WFC_Price']))
# Out:
# 0.5654242208372917
# 0.21224368480419697
# -0.27494718398994394

# %%
#Correlation
clean_finstock.corr()
# Out:
#            JPM_Price  BAC_Price  WFC_Price
# JPM_Price   1.000000   0.931912   0.554687
# BAC_Price   0.931912   1.000000   0.743532
# WFC_Price   0.554687   0.743532   1.000000

# %%
#Heatmap for illustrating correlation
plt.figure(figsize=(8,8))
sns.heatmap(clean_finstock.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>
